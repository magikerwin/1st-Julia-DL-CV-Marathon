# %% [markdown]
# # Julia Multiple Dispatch (多重分派)

# %% [markdown]
# ## 1. Multiple Dispatch (多重分派)
#
# 多重分派被認為是 Julia 語言中最強大的單一特性 (在官方文件中指出: "... multiple dispatch on the types of values is perhaps the single most powerful and central feature of the Julia language.")
#
# 多重分派的觸發時機是在執行期間 (runtime), 呼叫函式時根據傳入引數 (argument) 的數目及型別, 判斷應該呼叫的方法 (method). 之所以稱之為 **multiple** dispatch 的原因是, Julia 判斷時是根據所有引數, 而非像在某些程式語言中是根據第一個引數做判斷.
#
# 與多重分派相似的程式語言概念是 _Function Overloading_, 最大的不同點在於, Function Overloading 的觸發時機點在編譯 (compile time) 期間.
#
# ### 1.1 Methods
#
# Julia 內建的函式均已使用多重分派實作, 例如下面的例子, 使用 `methods()` 函式列出加法函式的實作定義, 可以看到因多重分派, 我們可以傳入不同型別的值到加法函式中進行運算.
#
# Method 是 Function (函式) 的行為 (behavior) 定義, 一個函式可以被定義多個行為, 也就是多個 Method, 在 Method 中再去進行不同的實作.

# %%
methods(+)
# Out:
# # 166 methods for generic function "+":
# [1] +(x::Bool, z::Complex{Bool}) in Base at complex.jl:286
# [2] +(x::Bool, y::Bool) in Base at bool.jl:96
# [3] +(x::Bool) in Base at bool.jl:93
# [4] +(x::Bool, y::T) where T<:AbstractFloat in Base at bool.jl:104
# [5] +(x::Bool, z::Complex) in Base at complex.jl:293
# [6] +(a::Float16, b::Float16) in Base at float.jl:398
# [7] +(x::Float32, y::Float32) in Base at float.jl:400
# [8] +(x::Float64, y::Float64) in Base at float.jl:401
# [9] +(z::Complex{Bool}, x::Bool) in Base at complex.jl:287
# [10] +(z::Complex{Bool}, x::Real) in Base at complex.jl:301
# [11] +(::Missing, ::Missing) in Base at missing.jl:114
# [12] +(::Missing) in Base at missing.jl:100
# [13] +(::Missing, ::Number) in Base at missing.jl:115
# [14] +(level::Base.CoreLogging.LogLevel, inc::Integer) in Base.CoreLogging at logging.jl:107
# [15] +(c::BigInt, x::BigFloat) in Base.MPFR at mpfr.jl:414
# [16] +(a::BigInt, b::BigInt, c::BigInt, d::BigInt, e::BigInt) in Base.GMP at gmp.jl:515
# [17] +(a::BigInt, b::BigInt, c::BigInt, d::BigInt) in Base.GMP at gmp.jl:514
# [18] +(a::BigInt, b::BigInt, c::BigInt) in Base.GMP at gmp.jl:513
# [19] +(x::BigInt, y::BigInt) in Base.GMP at gmp.jl:473
# [20] +(x::BigInt, c::Union{UInt16, UInt32, UInt8}) in Base.GMP at gmp.jl:521
# [21] +(x::BigInt, c::Union{Int16, Int32, Int8}) in Base.GMP at gmp.jl:527
# [22] +(a::BigFloat, b::BigFloat, c::BigFloat, d::BigFloat, e::BigFloat) in Base.MPFR at mpfr.jl:564
# [23] +(a::BigFloat, b::BigFloat, c::BigFloat, d::BigFloat) in Base.MPFR at mpfr.jl:557
# [24] +(a::BigFloat, b::BigFloat, c::BigFloat) in Base.MPFR at mpfr.jl:551
# [25] +(x::BigFloat, c::BigInt) in Base.MPFR at mpfr.jl:410
# [26] +(x::BigFloat, y::BigFloat) in Base.MPFR at mpfr.jl:379
# [27] +(x::BigFloat, c::Union{UInt16, UInt32, UInt8}) in Base.MPFR at mpfr.jl:386
# [28] +(x::BigFloat, c::Union{Int16, Int32, Int8}) in Base.MPFR at mpfr.jl:394
# [29] +(x::BigFloat, c::Union{Float16, Float32, Float64}) in Base.MPFR at mpfr.jl:402
# [30] +(x::Dates.CompoundPeriod, y::Dates.CompoundPeriod) in Dates at C:\Users\qwerz\AppData\Local\Programs\Julia\Julia-1.4.0\share\julia\stdlib\v1.4\Dates\src\periods.jl:341
# [31] +(x::Dates.CompoundPeriod, y::Dates.Period) in Dates at C:\Users\qwerz\AppData\Local\Programs\Julia\Julia-1.4.0\share\julia\stdlib\v1.4\Dates\src\periods.jl:339
# [32] +(x::Dates.CompoundPeriod, y::Dates.TimeType) in Dates at C:\Users\qwerz\AppData\Local\Programs\Julia\Julia-1.4.0\share\julia\stdlib\v1.4\Dates\src\periods.jl:369
# [33] +(x::Dates.Date, y::Dates.Day) in Dates at C:\Users\qwerz\AppData\Local\Programs\Julia\Julia-1.4.0\share\julia\stdlib\v1.4\Dates\src\arithmetic.jl:74
# [34] +(x::Dates.Date, y::Dates.Week) in Dates at C:\Users\qwerz\AppData\Local\Programs\Julia\Julia-1.4.0\share\julia\stdlib\v1.4\Dates\src\arithmetic.jl:72
# [35] +(dt::Dates.Date, z::Dates.Month) in Dates at C:\Users\qwerz\AppData\Local\Programs\Julia\Julia-1.4.0\share\julia\stdlib\v1.4\Dates\src\arithmetic.jl:55
# [36] +(dt::Dates.Date, y::Dates.Year) in Dates at C:\Users\qwerz\AppData\Local\Programs\Julia\Julia-1.4.0\share\julia\stdlib\v1.4\Dates\src\arithmetic.jl:28
# [37] +(dt::Dates.Date, t::Dates.Time) in Dates at C:\Users\qwerz\AppData\Local\Programs\Julia\Julia-1.4.0\share\julia\stdlib\v1.4\Dates\src\arithmetic.jl:19
# [38] +(t::Dates.Time, dt::Dates.Date) in Dates at C:\Users\qwerz\AppData\Local\Programs\Julia\Julia-1.4.0\share\julia\stdlib\v1.4\Dates\src\arithmetic.jl:20
# [39] +(x::Dates.Time, y::Dates.TimePeriod) in Dates at C:\Users\qwerz\AppData\Local\Programs\Julia\Julia-1.4.0\share\julia\stdlib\v1.4\Dates\src\arithmetic.jl:78
# [40] +(dt::Dates.DateTime, z::Dates.Month) in Dates at C:\Users\qwerz\AppData\Local\Programs\Julia\Julia-1.4.0\share\julia\stdlib\v1.4\Dates\src\arithmetic.jl:48
# [41] +(dt::Dates.DateTime, y::Dates.Year) in Dates at C:\Users\qwerz\AppData\Local\Programs\Julia\Julia-1.4.0\share\julia\stdlib\v1.4\Dates\src\arithmetic.jl:24
# [42] +(x::Dates.DateTime, y::Dates.Period) in Dates at C:\Users\qwerz\AppData\Local\Programs\Julia\Julia-1.4.0\share\julia\stdlib\v1.4\Dates\src\arithmetic.jl:76
# [43] +(B::BitArray{2}, J::LinearAlgebra.UniformScaling) in LinearAlgebra at C:\Users\qwerz\AppData\Local\Programs\Julia\Julia-1.4.0\share\julia\stdlib\v1.4\LinearAlgebra\src\uniformscaling.jl:115
# [44] +(a::Pkg.Resolve.VersionWeight, b::Pkg.Resolve.VersionWeight) in Pkg.Resolve at C:\Users\qwerz\AppData\Local\Programs\Julia\Julia-1.4.0\share\julia\stdlib\v1.4\Pkg\src\Resolve\versionweights.jl:22
# [45] +(a::Pkg.Resolve.FieldValue, b::Pkg.Resolve.FieldValue) in Pkg.Resolve at C:\Users\qwerz\AppData\Local\Programs\Julia\Julia-1.4.0\share\julia\stdlib\v1.4\Pkg\src\Resolve\fieldvalues.jl:43
# [46] +(y::AbstractFloat, x::Bool) in Base at bool.jl:106
# [47] +(x::T, y::T) where T<:Union{Int128, Int16, Int32, Int64, Int8, UInt128, UInt16, UInt32, UInt64, UInt8} in Base at int.jl:53
# [48] +(c::Union{UInt16, UInt32, UInt8}, x::BigInt) in Base.GMP at gmp.jl:522
# [49] +(c::Union{Int16, Int32, Int8}, x::BigInt) in Base.GMP at gmp.jl:528
# [50] +(a::Integer, b::Integer) in Base at int.jl:857
# [51] +(x::Integer, y::Ptr) in Base at pointer.jl:161
# [52] +(z::Complex) in Base at complex.jl:273
# [53] +(z::Complex, w::Complex) in Base at complex.jl:275
# [54] +(z::Complex, x::Bool) in Base at complex.jl:294
# [55] +(x::Rational) in Base at rational.jl:247
# [56] +(x::Real, z::Complex{Bool}) in Base at complex.jl:300
# [57] +(x::Real, z::Complex) in Base at complex.jl:312
# [58] +(z::Complex, x::Real) in Base at complex.jl:313
# [59] +(x::Rational, y::Rational) in Base at rational.jl:263
# [60] +(x::Integer, y::AbstractChar) in Base at char.jl:224
# [61] +(c::Union{UInt16, UInt32, UInt8}, x::BigFloat) in Base.MPFR at mpfr.jl:390
# [62] +(c::Union{Int16, Int32, Int8}, x::BigFloat) in Base.MPFR at mpfr.jl:398
# [63] +(c::Union{Float16, Float32, Float64}, x::BigFloat) in Base.MPFR at mpfr.jl:406
# [64] +(x::AbstractIrrational, y::AbstractIrrational) in Base at irrationals.jl:137
# [65] +(x::Number) in Base at operators.jl:504
# [66] +(x::T, y::T) where T<:Number in Base at promotion.jl:384
# [67] +(x::Number, y::Number) in Base at promotion.jl:311
# [68] +(r1::OrdinalRange, r2::OrdinalRange) in Base at range.jl:1011
# [69] +(r1::LinRange{T}, r2::LinRange{T}) where T in Base at range.jl:1018
# [70] +(r1::StepRangeLen{T,R,S} where S, r2::StepRangeLen{T,R,S} where S) where {R<:Base.TwicePrecision, T} in Base at twiceprecision.jl:557
# [71] +(r1::StepRangeLen{T,S,S1} where S1, r2::StepRangeLen{T,S,S1} where S1) where {T, S} in Base at range.jl:1034
# [72] +(r1::Union{LinRange, OrdinalRange, StepRangeLen}, r2::Union{LinRange, OrdinalRange, StepRangeLen}) in Base at range.jl:1026
# [73] +(x::Ptr, y::Integer) in Base at pointer.jl:159
# [74] +(x::Base.TwicePrecision, y::Number) in Base at twiceprecision.jl:265
# [75] +(x::Number, y::Base.TwicePrecision) in Base at twiceprecision.jl:268
# [76] +(x::Base.TwicePrecision{T}, y::Base.TwicePrecision{T}) where T in Base at twiceprecision.jl:271
# [77] +(x::Base.TwicePrecision, y::Base.TwicePrecision) in Base at twiceprecision.jl:275
# [78] +(A::Array, Bs::Array...) in Base at arraymath.jl:44
# [79] +(A::BitArray, B::BitArray) in Base at bitarray.jl:1106
# [80] +(r::AbstractRange{#s662} where #s662<:Dates.TimeType, x::Dates.Period) in Dates at C:\Users\qwerz\AppData\Local\Programs\Julia\Julia-1.4.0\share\julia\stdlib\v1.4\Dates\src\ranges.jl:59
# [81] +(A::Array, B::SparseArrays.AbstractSparseMatrixCSC) in SparseArrays at C:\Users\qwerz\AppData\Local\Programs\Julia\Julia-1.4.0\share\julia\stdlib\v1.4\SparseArrays\src\sparsematrix.jl:1652
# [82] +(x::Union{DenseArray{#s662,N}, Base.ReinterpretArray{#s662,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray}, Base.ReshapedArray{#s662,N,A,MI} where MI<:Tuple{Vararg{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray}, SubArray{#s662,N,A,I,L} where L where I<:Tuple{Vararg{Union{Int64, AbstractRange{Int64}, Base.AbstractCartesianIndex},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, Base.ReshapedArray{T,N,A,MI} where MI<:Tuple{Vararg{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, DenseArray}} where N where #s662<:Union{Dates.CompoundPeriod, Dates.Period}) in Dates at C:\Users\qwerz\AppData\Local\Programs\Julia\Julia-1.4.0\share\julia\stdlib\v1.4\Dates\src\deprecated.jl:57
# [83] +(x::Union{DenseArray{#s662,N}, Base.ReinterpretArray{#s662,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray}, Base.ReshapedArray{#s662,N,A,MI} where MI<:Tuple{Vararg{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray}, SubArray{#s662,N,A,I,L} where L where I<:Tuple{Vararg{Union{Int64, AbstractRange{Int64}, Base.AbstractCartesianIndex},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, Base.ReshapedArray{T,N,A,MI} where MI<:Tuple{Vararg{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, DenseArray}} where N where #s662<:Union{Dates.CompoundPeriod, Dates.Period}, y::Dates.TimeType) in Dates at C:\Users\qwerz\AppData\Local\Programs\Julia\Julia-1.4.0\share\julia\stdlib\v1.4\Dates\src\deprecated.jl:12
# [84] +(X::Union{DenseArray{#s662,N}, Base.ReinterpretArray{#s662,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray}, Base.ReshapedArray{#s662,N,A,MI} where MI<:Tuple{Vararg{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray}, SubArray{#s662,N,A,I,L} where L where I<:Tuple{Vararg{Union{Int64, AbstractRange{Int64}, Base.AbstractCartesianIndex},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, Base.ReshapedArray{T,N,A,MI} where MI<:Tuple{Vararg{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, DenseArray}} where N where #s662<:Union{Dates.CompoundPeriod, Dates.Period}, Y::Union{DenseArray{#s661,N}, Base.ReinterpretArray{#s661,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray}, Base.ReshapedArray{#s661,N,A,MI} where MI<:Tuple{Vararg{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray}, SubArray{#s661,N,A,I,L} where L where I<:Tuple{Vararg{Union{Int64, AbstractRange{Int64}, Base.AbstractCartesianIndex},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, Base.ReshapedArray{T,N,A,MI} where MI<:Tuple{Vararg{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, DenseArray}} where N where #s661<:Union{Dates.CompoundPeriod, Dates.Period}) in Dates at C:\Users\qwerz\AppData\Local\Programs\Julia\Julia-1.4.0\share\julia\stdlib\v1.4\Dates\src\deprecated.jl:64
# [85] +(A::LinearAlgebra.SymTridiagonal, B::LinearAlgebra.SymTridiagonal) in LinearAlgebra at C:\Users\qwerz\AppData\Local\Programs\Julia\Julia-1.4.0\share\julia\stdlib\v1.4\LinearAlgebra\src\tridiag.jl:158
# [86] +(A::LinearAlgebra.Tridiagonal, B::LinearAlgebra.Tridiagonal) in LinearAlgebra at C:\Users\qwerz\AppData\Local\Programs\Julia\Julia-1.4.0\share\julia\stdlib\v1.4\LinearAlgebra\src\tridiag.jl:657
# [87] +(A::LinearAlgebra.UpperTriangular, B::LinearAlgebra.UpperTriangular) in LinearAlgebra at C:\Users\qwerz\AppData\Local\Programs\Julia\Julia-1.4.0\share\julia\stdlib\v1.4\LinearAlgebra\src\triangular.jl:648
# [88] +(A::LinearAlgebra.LowerTriangular, B::LinearAlgebra.LowerTriangular) in LinearAlgebra at C:\Users\qwerz\AppData\Local\Programs\Julia\Julia-1.4.0\share\julia\stdlib\v1.4\LinearAlgebra\src\triangular.jl:649
# [89] +(A::LinearAlgebra.UpperTriangular, B::LinearAlgebra.UnitUpperTriangular) in LinearAlgebra at C:\Users\qwerz\AppData\Local\Programs\Julia\Julia-1.4.0\share\julia\stdlib\v1.4\LinearAlgebra\src\triangular.jl:650
# [90] +(A::LinearAlgebra.LowerTriangular, B::LinearAlgebra.UnitLowerTriangular) in LinearAlgebra at C:\Users\qwerz\AppData\Local\Programs\Julia\Julia-1.4.0\share\julia\stdlib\v1.4\LinearAlgebra\src\triangular.jl:651
# [91] +(A::LinearAlgebra.UnitUpperTriangular, B::LinearAlgebra.UpperTriangular) in LinearAlgebra at C:\Users\qwerz\AppData\Local\Programs\Julia\Julia-1.4.0\share\julia\stdlib\v1.4\LinearAlgebra\src\triangular.jl:652
# [92] +(A::LinearAlgebra.UnitLowerTriangular, B::LinearAlgebra.LowerTriangular) in LinearAlgebra at C:\Users\qwerz\AppData\Local\Programs\Julia\Julia-1.4.0\share\julia\stdlib\v1.4\LinearAlgebra\src\triangular.jl:653
# [93] +(A::LinearAlgebra.UnitUpperTriangular, B::LinearAlgebra.UnitUpperTriangular) in LinearAlgebra at C:\Users\qwerz\AppData\Local\Programs\Julia\Julia-1.4.0\share\julia\stdlib\v1.4\LinearAlgebra\src\triangular.jl:654
# [94] +(A::LinearAlgebra.UnitLowerTriangular, B::LinearAlgebra.UnitLowerTriangular) in LinearAlgebra at C:\Users\qwerz\AppData\Local\Programs\Julia\Julia-1.4.0\share\julia\stdlib\v1.4\LinearAlgebra\src\triangular.jl:655
# [95] +(A::LinearAlgebra.AbstractTriangular, B::LinearAlgebra.AbstractTriangular) in LinearAlgebra at C:\Users\qwerz\AppData\Local\Programs\Julia\Julia-1.4.0\share\julia\stdlib\v1.4\LinearAlgebra\src\triangular.jl:656
# [96] +(A::LinearAlgebra.Symmetric, B::LinearAlgebra.Symmetric) in LinearAlgebra at C:\Users\qwerz\AppData\Local\Programs\Julia\Julia-1.4.0\share\julia\stdlib\v1.4\LinearAlgebra\src\symmetric.jl:465
# [97] +(A::LinearAlgebra.Hermitian, B::LinearAlgebra.Hermitian) in LinearAlgebra at C:\Users\qwerz\AppData\Local\Programs\Julia\Julia-1.4.0\share\julia\stdlib\v1.4\LinearAlgebra\src\symmetric.jl:466
# [98] +(A::LinearAlgebra.Hermitian, B::LinearAlgebra.Symmetric{#s662,S} where S<:(AbstractArray{#s6621,2} where #s6621<:#s662) where #s662<:Real) in LinearAlgebra at C:\Users\qwerz\AppData\Local\Programs\Julia\Julia-1.4.0\share\julia\stdlib\v1.4\LinearAlgebra\src\symmetric.jl:467
# [99] +(A::LinearAlgebra.Symmetric{#s662,S} where S<:(AbstractArray{#s6621,2} where #s6621<:#s662) where #s662<:Real, B::LinearAlgebra.Hermitian) in LinearAlgebra at C:\Users\qwerz\AppData\Local\Programs\Julia\Julia-1.4.0\share\julia\stdlib\v1.4\LinearAlgebra\src\symmetric.jl:468
# [100] +(Da::LinearAlgebra.Diagonal, Db::LinearAlgebra.Diagonal) in LinearAlgebra at C:\Users\qwerz\AppData\Local\Programs\Julia\Julia-1.4.0\share\julia\stdlib\v1.4\LinearAlgebra\src\diagonal.jl:156
# [101] +(A::LinearAlgebra.Bidiagonal, B::LinearAlgebra.Bidiagonal) in LinearAlgebra at C:\Users\qwerz\AppData\Local\Programs\Julia\Julia-1.4.0\share\julia\stdlib\v1.4\LinearAlgebra\src\bidiag.jl:309
# [102] +(UL::LinearAlgebra.UnitUpperTriangular, J::LinearAlgebra.UniformScaling) in LinearAlgebra at C:\Users\qwerz\AppData\Local\Programs\Julia\Julia-1.4.0\share\julia\stdlib\v1.4\LinearAlgebra\src\uniformscaling.jl:131
# [103] +(UL::LinearAlgebra.UnitLowerTriangular, J::LinearAlgebra.UniformScaling) in LinearAlgebra at C:\Users\qwerz\AppData\Local\Programs\Julia\Julia-1.4.0\share\julia\stdlib\v1.4\LinearAlgebra\src\uniformscaling.jl:131
# [104] +(A::LinearAlgebra.Hermitian, J::LinearAlgebra.UniformScaling{#s662} where #s662<:Complex) in LinearAlgebra at C:\Users\qwerz\AppData\Local\Programs\Julia\Julia-1.4.0\share\julia\stdlib\v1.4\LinearAlgebra\src\uniformscaling.jl:145
# [105] +(H::LinearAlgebra.UpperHessenberg, J::LinearAlgebra.UniformScaling) in LinearAlgebra at C:\Users\qwerz\AppData\Local\Programs\Julia\Julia-1.4.0\share\julia\stdlib\v1.4\LinearAlgebra\src\hessenberg.jl:106
# [106] +(A::LinearAlgebra.Tridiagonal{#s662,V} where V<:AbstractArray{#s662,1} where #s662<:Number, B::LinearAlgebra.UniformScaling) in LinearAlgebra at C:\Users\qwerz\AppData\Local\Programs\Julia\Julia-1.4.0\share\julia\stdlib\v1.4\LinearAlgebra\src\special.jl:238
# [107] +(A::LinearAlgebra.SymTridiagonal{#s662,V} where V<:AbstractArray{#s662,1} where #s662<:Number, B::LinearAlgebra.UniformScaling) in LinearAlgebra at C:\Users\qwerz\AppData\Local\Programs\Julia\Julia-1.4.0\share\julia\stdlib\v1.4\LinearAlgebra\src\special.jl:243
# [108] +(A::LinearAlgebra.Bidiagonal{#s662,V} where V<:AbstractArray{#s662,1} where #s662<:Number, B::LinearAlgebra.UniformScaling) in LinearAlgebra at C:\Users\qwerz\AppData\Local\Programs\Julia\Julia-1.4.0\share\julia\stdlib\v1.4\LinearAlgebra\src\special.jl:248
# [109] +(A::LinearAlgebra.Diagonal{#s662,V} where V<:AbstractArray{#s662,1} where #s662<:Number, B::LinearAlgebra.UniformScaling) in LinearAlgebra at C:\Users\qwerz\AppData\Local\Programs\Julia\Julia-1.4.0\share\julia\stdlib\v1.4\LinearAlgebra\src\special.jl:253
# [110] +(A::SparseArrays.AbstractSparseMatrixCSC, J::LinearAlgebra.UniformScaling) in SparseArrays at C:\Users\qwerz\AppData\Local\Programs\Julia\Julia-1.4.0\share\julia\stdlib\v1.4\SparseArrays\src\sparsematrix.jl:3610
# [111] +(A::AbstractArray{T,2} where T, J::LinearAlgebra.UniformScaling) in LinearAlgebra at C:\Users\qwerz\AppData\Local\Programs\Julia\Julia-1.4.0\share\julia\stdlib\v1.4\LinearAlgebra\src\uniformscaling.jl:164
# [112] +(A::LinearAlgebra.UpperHessenberg, B::LinearAlgebra.UpperHessenberg) in LinearAlgebra at C:\Users\qwerz\AppData\Local\Programs\Julia\Julia-1.4.0\share\julia\stdlib\v1.4\LinearAlgebra\src\hessenberg.jl:101
# [113] +(A::LinearAlgebra.UpperTriangular, B::LinearAlgebra.Bidiagonal) in LinearAlgebra at C:\Users\qwerz\AppData\Local\Programs\Julia\Julia-1.4.0\share\julia\stdlib\v1.4\LinearAlgebra\src\special.jl:98
# [114] +(A::LinearAlgebra.Bidiagonal, B::LinearAlgebra.UpperTriangular) in LinearAlgebra at C:\Users\qwerz\AppData\Local\Programs\Julia\Julia-1.4.0\share\julia\stdlib\v1.4\LinearAlgebra\src\special.jl:106
# [115] +(A::LinearAlgebra.UnitUpperTriangular, B::LinearAlgebra.Bidiagonal) in LinearAlgebra at C:\Users\qwerz\AppData\Local\Programs\Julia\Julia-1.4.0\share\julia\stdlib\v1.4\LinearAlgebra\src\special.jl:98
# [116] +(A::LinearAlgebra.Bidiagonal, B::LinearAlgebra.UnitUpperTriangular) in LinearAlgebra at C:\Users\qwerz\AppData\Local\Programs\Julia\Julia-1.4.0\share\julia\stdlib\v1.4\LinearAlgebra\src\special.jl:106
# [117] +(A::LinearAlgebra.LowerTriangular, B::LinearAlgebra.Bidiagonal) in LinearAlgebra at C:\Users\qwerz\AppData\Local\Programs\Julia\Julia-1.4.0\share\julia\stdlib\v1.4\LinearAlgebra\src\special.jl:98
# [118] +(A::LinearAlgebra.Bidiagonal, B::LinearAlgebra.LowerTriangular) in LinearAlgebra at C:\Users\qwerz\AppData\Local\Programs\Julia\Julia-1.4.0\share\julia\stdlib\v1.4\LinearAlgebra\src\special.jl:106
# [119] +(A::LinearAlgebra.UnitLowerTriangular, B::LinearAlgebra.Bidiagonal) in LinearAlgebra at C:\Users\qwerz\AppData\Local\Programs\Julia\Julia-1.4.0\share\julia\stdlib\v1.4\LinearAlgebra\src\special.jl:98
# [120] +(A::LinearAlgebra.Bidiagonal, B::LinearAlgebra.UnitLowerTriangular) in LinearAlgebra at C:\Users\qwerz\AppData\Local\Programs\Julia\Julia-1.4.0\share\julia\stdlib\v1.4\LinearAlgebra\src\special.jl:106
# [121] +(A::LinearAlgebra.Bidiagonal, B::LinearAlgebra.Diagonal) in LinearAlgebra at C:\Users\qwerz\AppData\Local\Programs\Julia\Julia-1.4.0\share\julia\stdlib\v1.4\LinearAlgebra\src\special.jl:127
# [122] +(A::LinearAlgebra.Diagonal, B::LinearAlgebra.Bidiagonal) in LinearAlgebra at C:\Users\qwerz\AppData\Local\Programs\Julia\Julia-1.4.0\share\julia\stdlib\v1.4\LinearAlgebra\src\special.jl:137
# [123] +(A::LinearAlgebra.Diagonal, B::LinearAlgebra.SymTridiagonal) in LinearAlgebra at C:\Users\qwerz\AppData\Local\Programs\Julia\Julia-1.4.0\share\julia\stdlib\v1.4\LinearAlgebra\src\special.jl:147
# [124] +(A::LinearAlgebra.SymTridiagonal, B::LinearAlgebra.Diagonal) in LinearAlgebra at C:\Users\qwerz\AppData\Local\Programs\Julia\Julia-1.4.0\share\julia\stdlib\v1.4\LinearAlgebra\src\special.jl:157
# [125] +(A::LinearAlgebra.Tridiagonal, B::LinearAlgebra.SymTridiagonal) in LinearAlgebra at C:\Users\qwerz\AppData\Local\Programs\Julia\Julia-1.4.0\share\julia\stdlib\v1.4\LinearAlgebra\src\special.jl:168
# [126] +(A::LinearAlgebra.SymTridiagonal, B::LinearAlgebra.Tridiagonal) in LinearAlgebra at C:\Users\qwerz\AppData\Local\Programs\Julia\Julia-1.4.0\share\julia\stdlib\v1.4\LinearAlgebra\src\special.jl:170
# [127] +(A::LinearAlgebra.Diagonal, B::LinearAlgebra.Tridiagonal) in LinearAlgebra at C:\Users\qwerz\AppData\Local\Programs\Julia\Julia-1.4.0\share\julia\stdlib\v1.4\LinearAlgebra\src\special.jl:175
# [128] +(A::LinearAlgebra.Tridiagonal, B::LinearAlgebra.Diagonal) in LinearAlgebra at C:\Users\qwerz\AppData\Local\Programs\Julia\Julia-1.4.0\share\julia\stdlib\v1.4\LinearAlgebra\src\special.jl:185
# [129] +(A::LinearAlgebra.Bidiagonal, B::LinearAlgebra.Tridiagonal) in LinearAlgebra at C:\Users\qwerz\AppData\Local\Programs\Julia\Julia-1.4.0\share\julia\stdlib\v1.4\LinearAlgebra\src\special.jl:195
# [130] +(A::LinearAlgebra.Tridiagonal, B::LinearAlgebra.Bidiagonal) in LinearAlgebra at C:\Users\qwerz\AppData\Local\Programs\Julia\Julia-1.4.0\share\julia\stdlib\v1.4\LinearAlgebra\src\special.jl:205
# [131] +(A::LinearAlgebra.Bidiagonal, B::LinearAlgebra.SymTridiagonal) in LinearAlgebra at C:\Users\qwerz\AppData\Local\Programs\Julia\Julia-1.4.0\share\julia\stdlib\v1.4\LinearAlgebra\src\special.jl:215
# [132] +(A::LinearAlgebra.SymTridiagonal, B::LinearAlgebra.Bidiagonal) in LinearAlgebra at C:\Users\qwerz\AppData\Local\Programs\Julia\Julia-1.4.0\share\julia\stdlib\v1.4\LinearAlgebra\src\special.jl:225
# [133] +(A::SparseArrays.AbstractSparseMatrixCSC, B::SparseArrays.AbstractSparseMatrixCSC) in SparseArrays at C:\Users\qwerz\AppData\Local\Programs\Julia\Julia-1.4.0\share\julia\stdlib\v1.4\SparseArrays\src\sparsematrix.jl:1648
# [134] +(A::SparseArrays.AbstractSparseMatrixCSC, B::Array) in SparseArrays at C:\Users\qwerz\AppData\Local\Programs\Julia\Julia-1.4.0\share\julia\stdlib\v1.4\SparseArrays\src\sparsematrix.jl:1651
# [135] +(x::SparseArrays.AbstractSparseArray{Tv,Ti,1} where Ti where Tv, y::SparseArrays.AbstractSparseArray{Tv,Ti,1} where Ti where Tv) in SparseArrays at C:\Users\qwerz\AppData\Local\Programs\Julia\Julia-1.4.0\share\julia\stdlib\v1.4\SparseArrays\src\sparsevector.jl:1303
# [136] +(x::AbstractArray{#s69,N} where N where #s69<:Number) in Base at abstractarraymath.jl:97
# [137] +(A::AbstractArray, B::AbstractArray) in Base at arraymath.jl:38
# [138] +(x::T, y::Integer) where T<:AbstractChar in Base at char.jl:223
# [139] +(index1::CartesianIndex{N}, index2::CartesianIndex{N}) where N in Base.IteratorsMD at multidimensional.jl:111
# [140] +(::Number, ::Missing) in Base at missing.jl:116
# [141] +(x::P, y::P) where P<:Dates.Period in Dates at C:\Users\qwerz\AppData\Local\Programs\Julia\Julia-1.4.0\share\julia\stdlib\v1.4\Dates\src\periods.jl:75
# [142] +(x::Dates.Period, y::Dates.Period) in Dates at C:\Users\qwerz\AppData\Local\Programs\Julia\Julia-1.4.0\share\julia\stdlib\v1.4\Dates\src\periods.jl:338
# [143] +(y::Dates.Period, x::Dates.CompoundPeriod) in Dates at C:\Users\qwerz\AppData\Local\Programs\Julia\Julia-1.4.0\share\julia\stdlib\v1.4\Dates\src\periods.jl:340
# [144] +(x::Union{Dates.CompoundPeriod, Dates.Period}) in Dates at C:\Users\qwerz\AppData\Local\Programs\Julia\Julia-1.4.0\share\julia\stdlib\v1.4\Dates\src\periods.jl:349
# [145] +(x::Dates.TimeType) in Dates at C:\Users\qwerz\AppData\Local\Programs\Julia\Julia-1.4.0\share\julia\stdlib\v1.4\Dates\src\arithmetic.jl:8
# [146] +(a::Dates.TimeType, b::Dates.Period, c::Dates.Period) in Dates at C:\Users\qwerz\AppData\Local\Programs\Julia\Julia-1.4.0\share\julia\stdlib\v1.4\Dates\src\periods.jl:360
# [147] +(a::Dates.TimeType, b::Dates.Period, c::Dates.Period, d::Dates.Period...) in Dates at C:\Users\qwerz\AppData\Local\Programs\Julia\Julia-1.4.0\share\julia\stdlib\v1.4\Dates\src\periods.jl:361
# [148] +(x::Dates.TimeType, y::Dates.CompoundPeriod) in Dates at C:\Users\qwerz\AppData\Local\Programs\Julia\Julia-1.4.0\share\julia\stdlib\v1.4\Dates\src\periods.jl:364
# [149] +(x::Dates.Instant) in Dates at C:\Users\qwerz\AppData\Local\Programs\Julia\Julia-1.4.0\share\julia\stdlib\v1.4\Dates\src\arithmetic.jl:4
# [150] +(y::Dates.Period, x::Dates.TimeType) in Dates at C:\Users\qwerz\AppData\Local\Programs\Julia\Julia-1.4.0\share\julia\stdlib\v1.4\Dates\src\arithmetic.jl:80
# [151] +(x::Dates.Period, r::AbstractRange{#s662} where #s662<:Dates.TimeType) in Dates at C:\Users\qwerz\AppData\Local\Programs\Julia\Julia-1.4.0\share\julia\stdlib\v1.4\Dates\src\ranges.jl:58
# [152] +(x::AbstractArray{#s662,N} where N where #s662<:Dates.TimeType, y::Union{Dates.CompoundPeriod, Dates.Period}) in Dates at C:\Users\qwerz\AppData\Local\Programs\Julia\Julia-1.4.0\share\julia\stdlib\v1.4\Dates\src\deprecated.jl:8
# [153] +(y::Union{Dates.CompoundPeriod, Dates.Period}, x::AbstractArray{#s662,N} where N where #s662<:Dates.TimeType) in Dates at C:\Users\qwerz\AppData\Local\Programs\Julia\Julia-1.4.0\share\julia\stdlib\v1.4\Dates\src\deprecated.jl:16
# [154] +(y::Dates.TimeType, x::Union{DenseArray{#s662,N}, Base.ReinterpretArray{#s662,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray}, Base.ReshapedArray{#s662,N,A,MI} where MI<:Tuple{Vararg{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray}, SubArray{#s662,N,A,I,L} where L where I<:Tuple{Vararg{Union{Int64, AbstractRange{Int64}, Base.AbstractCartesianIndex},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, Base.ReshapedArray{T,N,A,MI} where MI<:Tuple{Vararg{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, DenseArray}} where N where #s662<:Union{Dates.CompoundPeriod, Dates.Period}) in Dates at C:\Users\qwerz\AppData\Local\Programs\Julia\Julia-1.4.0\share\julia\stdlib\v1.4\Dates\src\deprecated.jl:20
# [155] +(J::LinearAlgebra.UniformScaling, x::Number) in LinearAlgebra at C:\Users\qwerz\AppData\Local\Programs\Julia\Julia-1.4.0\share\julia\stdlib\v1.4\LinearAlgebra\src\uniformscaling.jl:109
# [156] +(x::Number, J::LinearAlgebra.UniformScaling) in LinearAlgebra at C:\Users\qwerz\AppData\Local\Programs\Julia\Julia-1.4.0\share\julia\stdlib\v1.4\LinearAlgebra\src\uniformscaling.jl:110
# [157] +(J1::LinearAlgebra.UniformScaling, J2::LinearAlgebra.UniformScaling) in LinearAlgebra at C:\Users\qwerz\AppData\Local\Programs\Julia\Julia-1.4.0\share\julia\stdlib\v1.4\LinearAlgebra\src\uniformscaling.jl:114
# [158] +(J::LinearAlgebra.UniformScaling, B::BitArray{2}) in LinearAlgebra at C:\Users\qwerz\AppData\Local\Programs\Julia\Julia-1.4.0\share\julia\stdlib\v1.4\LinearAlgebra\src\uniformscaling.jl:116
# [159] +(A::LinearAlgebra.UniformScaling, B::LinearAlgebra.Tridiagonal{#s662,V} where V<:AbstractArray{#s662,1} where #s662<:Number) in LinearAlgebra at C:\Users\qwerz\AppData\Local\Programs\Julia\Julia-1.4.0\share\julia\stdlib\v1.4\LinearAlgebra\src\special.jl:257
# [160] +(A::LinearAlgebra.UniformScaling, B::LinearAlgebra.SymTridiagonal{#s662,V} where V<:AbstractArray{#s662,1} where #s662<:Number) in LinearAlgebra at C:\Users\qwerz\AppData\Local\Programs\Julia\Julia-1.4.0\share\julia\stdlib\v1.4\LinearAlgebra\src\special.jl:262
# [161] +(A::LinearAlgebra.UniformScaling, B::LinearAlgebra.Bidiagonal{#s662,V} where V<:AbstractArray{#s662,1} where #s662<:Number) in LinearAlgebra at C:\Users\qwerz\AppData\Local\Programs\Julia\Julia-1.4.0\share\julia\stdlib\v1.4\LinearAlgebra\src\special.jl:267
# [162] +(A::LinearAlgebra.UniformScaling, B::LinearAlgebra.Diagonal{#s662,V} where V<:AbstractArray{#s662,1} where #s662<:Number) in LinearAlgebra at C:\Users\qwerz\AppData\Local\Programs\Julia\Julia-1.4.0\share\julia\stdlib\v1.4\LinearAlgebra\src\special.jl:272
# [163] +(J::LinearAlgebra.UniformScaling, A::AbstractArray{T,2} where T) in LinearAlgebra at C:\Users\qwerz\AppData\Local\Programs\Julia\Julia-1.4.0\share\julia\stdlib\v1.4\LinearAlgebra\src\uniformscaling.jl:117
# [164] +(F::LinearAlgebra.Hessenberg, J::LinearAlgebra.UniformScaling) in LinearAlgebra at C:\Users\qwerz\AppData\Local\Programs\Julia\Julia-1.4.0\share\julia\stdlib\v1.4\LinearAlgebra\src\hessenberg.jl:559
# [165] +(J::LinearAlgebra.UniformScaling, F::LinearAlgebra.Hessenberg) in LinearAlgebra at C:\Users\qwerz\AppData\Local\Programs\Julia\Julia-1.4.0\share\julia\stdlib\v1.4\LinearAlgebra\src\hessenberg.jl:560
# [166] +(a, b, c, xs...) in Base at operators.jl:529

# %% [markdown]
# 若未透過 `::` 定義型別的話, 則是 `Any` 型別.

# %%
f(x::Number, y::Number) = 2x - 3y
f(x::Float64, y::Float64) = 2x - 3y
f(x, y) = println("Dispatched to Any")
# Out:
# f (generic function with 3 methods)

# %% [markdown]
# 呼叫 `methods()` 函式可以顯示 Function 中所有的 Method 定義, 以及其行數.

# %%
methods(f)
# Out:
# # 3 methods for generic function "f":
# [1] f(x::Float64, y::Float64) in Main at In[2]:2
# [2] f(x::Number, y::Number) in Main at In[2]:1
# [3] f(x, y) in Main at In[2]:3

# %% [markdown]
# 根據數目和傳入值的型別, Multiple Dispatch 會判斷應該要分派到哪一個 method. 多重分派會優先尋找最符合的定義來分派.

# %%
# 符合 Float64
f(5.0, 3.0)
# Out:
# 1.0

# %%
# 最符合 Number
f(5, 3)
# Out:
# 1

# %%
# 沒有定義 String 的 Method, 所以最符合的是 Any
f("5", "3")
# Out:
# Dispatched to Any

# %% [markdown]
# 透過 `@which` macro 巨集, 可以看到會被分派到哪一個 method.

# %%
@which f(5.0, 3.0)
# Out:
# f(x::Float64, y::Float64) in Main at In[2]:2

# %% [markdown]
# 含糊 (ambiguous) 的定義可能會造成 `MethodError`.

# %%
f2(x::Float64, y) = 2x - 3y
f2(x, y::Float64) = 2x - 3y

f2(2.0, 3.0)
# Out:
# MethodError: f2(::Float64, ::Float64) is ambiguous. Candidates:
#   f2(x::Float64, y) in Main at In[8]:1
#   f2(x, y::Float64) in Main at In[8]:2
# Possible fix, define
#   f2(::Float64, ::Float64)
#
# Stacktrace:
#  [1] top-level scope at In[8]:3

# %% [markdown]
# ### 1.2 型別參數化 (Type Parameter) 的 Method (Parametric Methods)
#
# Method 可以使用 **type** 參數做為引數的型別, 如下例示範, 傳入引數要屬於 Number 或是其子型別, 且 2 個引數型別相同.

# %%
f3(x::T, y::T) where{T<:Number} = 2x - 3y
# Out:
# f3 (generic function with 1 method)

# %%
f3(5, 3)
# Out:
# 1

# %%
# 傳入引數型別不同, 產生 MethodError
f3(5, 3.0)
# Out:
# MethodError: no method matching f3(::Int64, ::Float64)
# Closest candidates are:
#   f3(::T, !Matched::T) where T<:Number at In[9]:1
#
# Stacktrace:
#  [1] top-level scope at In[11]:1

# %%
# String 不屬於 Number 型別及其子型別, 所以會產生 MethodError
f3("123", "456")
# Out:
# MethodError: no method matching f3(::String, ::String)
#
# Stacktrace:
#  [1] top-level scope at In[12]:1
