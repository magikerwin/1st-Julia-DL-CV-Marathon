# %% [markdown]
# # 程式語言外部呼叫：在 Julia 內使用 Python

# %%
using Pkg
Pkg.add("PyCall")
# Out:
#    Updating registry at `C:\Users\qwerz\.julia\registries\General`
#    Updating git-repo `https://github.com/JuliaRegistries/General.git`
# Fetching: [========================================>]  100.0 %                                   ]  11.2 %Fetching: [=======>                                 ]  15.6 % %>                          ]  32.5 %                     ]  45.4 %]  51.2 %============================>            ]  67.8 %.2 %Fetching: [===============================>         ]  76.6 %81.0 %5 %
#   Resolving package versions...
#    Updating `C:\Users\qwerz\.julia\environments\v1.4\Project.toml`
#   [438e738f] + PyCall v1.91.4
#    Updating `C:\Users\qwerz\.julia\environments\v1.4\Manifest.toml`
#   [438e738f] + PyCall v1.91.4

# %%
using PyCall
# Out:
# ┌ Info: Precompiling PyCall [438e738f-606a-5dbb-bf0a-cddfbfd45ab0]
# └ @ Base loading.jl:1260

# %% [markdown]
# ## 簡單操作 Python

# %%
py"1 + 2"
# Out:
# 3

# %% [markdown]
# Python 物件在 Julia 語言的顯示會標記成 PyObject，以及 Python class。

# %%
py"type(1 + 2)"
# Out:
# PyObject <class 'int'>

# %% [markdown]
# ## 寫一段 Python code

# %% [markdown]
# 使用 PyCall 撰寫的程式碼不會顯示執行結果。

# %%
py"""
import numpy as np
np.sin(np.pi)
"""

# %% [markdown]
# 從 Julia 輸入資料，傳送到 Python 函式中處理。

# %%
py"np.sin"(1.0)
# Out:
# 0.8414709848078965

# %% [markdown]
# 試著處理 Julia 中的有理數，有理數在 Python 中沒有對應的類別。

# %%
py"np.sin"(1//2)
# Out:
# 0.479425538604203

# %% [markdown]
# 也可以傳送陣列給 Python 處理。

# %%
py"np.sin"([0.5π, π, 2π])
# Out:
# 3-element Array{Float64,1}:
#   1.0
#   1.2246467991473532e-16
#  -2.4492935982947064e-16

# %% [markdown]
# 或是將 Python 模組/套件載入，以 Julia 變數的方式呼叫 Python 模組/套件。

# %%
np = pyimport("numpy")
np.sin(1)
# Out:
# 0.8414709848078965

# %%
np.zeros([1,2])
# Out:
# 1×2 Array{Float64,2}:
#  0.0  0.0
