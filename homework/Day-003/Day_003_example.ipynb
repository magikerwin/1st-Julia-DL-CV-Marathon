# %% [markdown]
# # Julia 套件管理 (Package Management)

# %%
using Pkg

# %% [markdown]
# 呼叫 `installed()` 函數查看目前已安裝的套件。

# %%
Pkg.installed()
# Out:
# ┌ Warning: Pkg.installed() is deprecated
# └ @ Pkg D:\buildbot\worker\package_win64\build\usr\share\julia\stdlib\v1.4\Pkg\src\Pkg.jl:531
# Dict{String,VersionNumber} with 1 entry:
#   "IJulia" => v"1.21.1"

# %% [markdown]
# 如果要查看特定套件，可以加上套件名稱。

# %%
Pkg.installed()["IJulia"]
# Out:
# ┌ Warning: Pkg.installed() is deprecated
# └ @ Pkg D:\buildbot\worker\package_win64\build\usr\share\julia\stdlib\v1.4\Pkg\src\Pkg.jl:531
# v"1.21.1"

# %% [markdown]
# 安裝套件的最新版本符合 dependency 版本 (如果未指定版本)。
#
# 套件名稱的大小寫是有區別的，輸入時需留意。

# %%
Pkg.add("DataFrames")
# Out:
#    Updating registry at `C:\Users\qwerz\.julia\registries\General`
#    Updating git-repo `https://github.com/JuliaRegistries/General.git`
# Fetching: [========================================>]  1008 %%Fetching: [==>                                      ]  4.6 %.1 % % %14.4 %16.2 % %.9 %Fetching: [===========>                             ]  25.5 %9 %                            ]  28.7 %2 % %4 %================>                        ]  39.5 %5 %=================>                       ]  42.4 %                    ]  49.4 %======================>                  ]  53.6 %               ]  61.4 %]  62.7 %>             ]  65.0 %Fetching: [============================>            ]  69.4 %           ]  71.8 %.7 % %===============================>         ]  77.4 %Fetching: [================================>        ]  78.9 %=================================>       ]  80.6 %Fetching: [==================================>      ]  83.4 %.7 %   ]  90.2 %]  98.1 %.0 %
#   Resolving package versions...
#   Installed DataStructures ─ v0.17.11
#    Updating `C:\Users\qwerz\.julia\environments\v1.4\Project.toml`
#   [a93c6f00] + DataFrames v0.20.2
#    Updating `C:\Users\qwerz\.julia\environments\v1.4\Manifest.toml`
#   [324d7699] + CategoricalArrays v0.7.7
#   [34da2185] + Compat v3.8.0
#   [9a962f9c] + DataAPI v1.1.0
#   [a93c6f00] + DataFrames v0.20.2
#   [864edb3b] + DataStructures v0.17.11
#   [e2d170a0] + DataValueInterfaces v1.0.0
#   [41ab1584] + InvertedIndices v1.0.0
#   [82899510] + IteratorInterfaceExtensions v1.0.0
#   [e1d29d7a] + Missings v0.4.3
#   [bac558e1] + OrderedCollections v1.1.0
#   [2dfb63ee] + PooledArrays v0.5.3
#   [189a3867] + Reexport v0.2.0
#   [a2af1166] + SortingAlgorithms v0.3.1
#   [3783bdb8] + TableTraits v1.0.0
#   [bd369af6] + Tables v1.0.3
#   [8bb1440f] + DelimitedFiles
#   [9fa8497b] + Future
#   [37e2e46d] + LinearAlgebra
#   [1a1011a3] + SharedArrays
#   [2f01184e] + SparseArrays
#   [10745b16] + Statistics

# %% [markdown]
# 若有需要重新 build 套件，可以呼叫 `Pkg.build()` 函數。
#
# 沒有指定套件名稱的話，預設是 build 所有套件。

# %%
Pkg.build("IJulia")
# Out:
#    Building Conda ──→ `C:\Users\qwerz\.julia\packages\Conda\3rPhK\deps\build.log`
#    Building MbedTLS → `C:\Users\qwerz\.julia\packages\MbedTLS\a1JFn\deps\build.log`
#    Building IJulia ─→ `C:\Users\qwerz\.julia\packages\IJulia\yLI42\deps\build.log`

# %% [markdown]
# 若要安裝特定版本，可以使用下列語法指定版本編號。

# %%
Pkg.add(PackageSpec(name="PyCall", version="1.91.0"))
# Out:
#   Resolving package versions...
#   Installed MacroTools ─ v0.5.5
#   Installed PyCall ───── v1.91.0
#    Updating `C:\Users\qwerz\.julia\environments\v1.4\Project.toml`
#   [438e738f] + PyCall v1.91.0
#    Updating `C:\Users\qwerz\.julia\environments\v1.4\Manifest.toml`
#   [1914dd2f] + MacroTools v0.5.5
#   [438e738f] + PyCall v1.91.0
#    Building PyCall → `C:\Users\qwerz\.julia\packages\PyCall\1815y\deps\build.log`

# %% [markdown]
# 如果沒有指定套件名稱的話，`update()` 函數會更新所有可更新的套件。
# 如果要更新特定套件的話，也可以指明套件名稱，例如：`Pkg.update(“PyCall”)`。
#
# 在上面範例中刻意安裝較舊版本的 `PyCall`，執行更新後，可以看到 `PyCall` 被更新。

# %%
Pkg.update("PyCall")
# Out:
#    Updating registry at `C:\Users\qwerz\.julia\registries\General`
#    Updating git-repo `https://github.com/JuliaRegistries/General.git`
#   Installed Parsers ─ v1.0.1
#   Installed PyCall ── v1.91.4
#    Updating `C:\Users\qwerz\.julia\environments\v1.4\Project.toml`
#   [438e738f] ↑ PyCall v1.91.0 ⇒ v1.91.4
#    Updating `C:\Users\qwerz\.julia\environments\v1.4\Manifest.toml`
#   [69de0a69] ↑ Parsers v0.3.12 ⇒ v1.0.1
#   [438e738f] ↑ PyCall v1.91.0 ⇒ v1.91.4
#    Building PyCall → `C:\Users\qwerz\.julia\packages\PyCall\zqDXB\deps\build.log`

# %% [markdown]
# 刪除套件

# %%
Pkg.rm("PyCall")
# Out:
#    Updating `C:\Users\qwerz\.julia\environments\v1.4\Project.toml`
#   [438e738f] - PyCall v1.91.4
#    Updating `C:\Users\qwerz\.julia\environments\v1.4\Manifest.toml`
#   [1914dd2f] - MacroTools v0.5.5
#   [438e738f] - PyCall v1.91.4
